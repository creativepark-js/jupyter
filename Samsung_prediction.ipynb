# %%
import os
print(os.getcwd())
# Out:
# D:\IBA 동아리

# %%
os.listdir()
# Out:
# ["'펀다' 데이터 전처리 및 시각화.ipynb",
#  '.ipynb_checkpoints',
#  'data',
#  'iris 데이터 시각화.ipynb',
#  'Samsung_classification.ipynb',
#  'Samsung_prediction.ipynb',
#  'webscraping_basic',
#  '동아리 1주차',
#  '동아리 2주차',
#  '동아리 3주차',
#  '동아리 알바 웹크롤링.ipynb',
#  '동아리 타이타닉 전처리 및 시각화.ipynb',
#  '머신러닝 완벽가이드 1장.ipynb',
#  '머신러닝 완벽가이드 2장.ipynb',
#  '코딩도장 연습',
#  '타이타닉 모델링 2.ipynb',
#  '홍태호 교수님 시계열 특강.ipynb']

# %% [markdown]
# # 기초 설정

# %%
#필요 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

from sklearn.neural_network import MLPRegressor
import keras
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Activation
from tensorflow import keras
from tensorflow.keras import layers


def MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 
def RMSE(y_test, y_pred):
    return np.sqrt(((y_pred - y_test) ** 2).mean())

# %%
#데이터 불러오기
df = pd.read_csv('d:/IBA 동아리/data/samsung.csv', encoding = 'cp949', index_col = 0) #encoding 지정으로 한글깨짐 방지, 일자를 인덱스로 사용

# %%
#인덱스 날자형으로 변경하기
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#                 시가      고가      저가      종가         거래량
# 일자
# 2020-01-31  57,800  58,400  56,400  56,400  19,749,457
# 2020-01-30  58,800  58,800  56,800  57,200  20,821,939
# 2020-01-29  59,100  59,700  58,800  59,100  16,446,102
# 2020-01-28  59,400  59,400  58,300  58,800  23,664,541
# 2020-01-23  61,800  61,800  60,700  60,800  14,916,555

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 426 entries, 2020-01-31 to 2018-05-04
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시가      426 non-null    object
#  1   고가      426 non-null    object
#  2   저가      426 non-null    object
#  3   종가      426 non-null    object
#  4   거래량     426 non-null    object
# dtypes: object(5)
# memory usage: 20.0+ KB

# %%
#문자형 데이터 수치형 데이터로 변환

for i in range(len(df)):   #데이터의 행 개수 
    for j in range(df.shape[1]): # 데이터의 열 개수
        df.iloc[i,j] = df.iloc[i,j].replace(',','') # 콤마 지우기(replace 함수)
        

for i in range(df.shape[1]): #데이터 열 개수만큼
    df.iloc[:,i] = df.iloc[:,i].astype('int') #열마다 데이터 수치형으로 변경

# %% [markdown]
# # 데이터 탐색

# %%
# 결측치 탐색
df.isnull().sum()
# Out:
# 시가     0
# 고가     0
# 저가     0
# 종가     0
# 거래량    0
# dtype: int64

# %%
# 시가, 고가, 저가, 종가, 거래량 기초통계량(평균, 분산, 최소, 최대 등)
df.describe()
# Out:
#                  시가            고가            저가            종가           거래량
# count    426.000000    426.000000    426.000000    426.000000  4.260000e+02
# mean   46742.723005  47183.450704  46272.065728  46735.798122  1.143660e+07
# std     4509.621724   4517.591974   4433.557218   4470.252415  5.072198e+06
# min    37450.000000  37600.000000  36850.000000  37450.000000  4.406531e+06
# 25%    43912.500000  44350.000000  43550.000000  44000.000000  8.264758e+06
# 50%    46100.000000  46450.000000  45650.000000  46075.000000  1.043370e+07
# 75%    48975.000000  49237.500000  48537.500000  49012.500000  1.328609e+07
# max    62000.000000  62800.000000  61700.000000  62400.000000  6.349111e+07

# %%
#종가
plt.figure(figsize=(18,9))
sns.lineplot(x=df.index, y=df['종가'])
# Out:
# <AxesSubplot:xlabel='일자', ylabel='종가'>

# %% [markdown]
# # 주가지수 예측모형

# %%
#5_days ahead prediction(5영업일 이후 종가를 종속변수로 설정)
df['y'] = df['종가'].shift(5)

#7만큼 종가를 이전으로 가져왔기때문에 결측치 7개 존재
df = df.sort_index()
df.head(10)
# Out:
#                시가     고가     저가     종가       거래량        y
# 일자
# 2018-05-04  53000  53900  51800  51900  39565391  50100.0
# 2018-05-08  52600  53200  51900  52600  23104720  49200.0
# 2018-05-09  52600  52800  50900  50900  16128305  49850.0
# 2018-05-10  51700  51700  50600  51600  13905263  49400.0
# 2018-05-11  52000  52200  51200  51300  10314997  49500.0
# 2018-05-14  51000  51100  49900  50100  14909272  50000.0
# 2018-05-15  50200  50400  49100  49200  18709146  51800.0
# 2018-05-16  49200  50200  49150  49850  15918683  51400.0
# 2018-05-17  50300  50500  49400  49400  10365440  52700.0
# 2018-05-18  49900  49900  49350  49500   6706570  52300.0

# %%
#결측치 제거
df = df.dropna()

# %%
#입력변수 설정(시가, 저가, 고가, 종가, 거래량)
X = df.drop(columns = 'y')
#종속변수 설정(5영업일 뒤 종가)
y = df['y']

# %%
#학습용, 검증용 데이터셋 나누기(7:3, shuffle = False로 지정해 random sampling되지 않게 설정)
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.3, 
                                                    shuffle=False)

# %%
X_train
# Out:
#                시가     고가     저가     종가       거래량
# 일자
# 2018-05-04  53000  53900  51800  51900  39565391
# 2018-05-08  52600  53200  51900  52600  23104720
# 2018-05-09  52600  52800  50900  50900  16128305
# 2018-05-10  51700  51700  50600  51600  13905263
# 2018-05-11  52000  52200  51200  51300  10314997
# ...           ...    ...    ...    ...       ...
# 2019-07-11  46350  46550  46150  46200  10989751
# 2019-07-12  46350  46400  45800  46300   5245804
# 2019-07-15  45950  46650  45750  46450   4717226
# 2019-07-16  46450  46850  46300  46850   7407824
# 2019-07-17  46150  46350  45950  46050   5216602
#
# [294 rows x 5 columns]

# %%
X_test
# Out:
#                시가     고가     저가     종가       거래량
# 일자
# 2019-07-18  46450  46450  45650  46100   5143554
# 2019-07-19  46650  46950  46600  46800   8819393
# 2019-07-22  46800  47300  46600  47200   9009109
# 2019-07-23  47350  47550  47050  47300   9061381
# 2019-07-24  47100  47150  46250  46400   8756522
# ...           ...    ...    ...    ...       ...
# 2020-01-16  59100  60700  59000  60700  14381774
# 2020-01-17  61900  62000  61000  61300  16025661
# 2020-01-20  62000  62800  61700  62400  12528855
# 2020-01-21  62000  62400  61200  61400  11142693
# 2020-01-22  60500  62600  60400  62300  15339565
#
# [127 rows x 5 columns]

# %%
#확인
print("학습 데이터 개수:", X_train.shape[0])
print("평가 데이터 개수:", X_test.shape[0])
# Out:
# 학습 데이터 개수: 294
# 평가 데이터 개수: 127

# %% [markdown]
# # MA(5) 모형

# %%
#MA(5)예측값 생성 - 평가데이터 개수만큼
#rolling함수 사용해 이전 5일치 평균 활용해 예측값 생성
pred_MA = df['y'].rolling(window = 5).mean()[293:]

#성과지표 확인
print('MAPE:', MAPE(pred_MA, y_test))
print('RMSE', RMSE(pred_MA, y_test))
# Out:
# MAPE: 1.424420889733661
# RMSE 937.8039189916998

# %%
plt.figure(figsize = (16,8))
plt.plot(y_test, label = 'real')
plt.plot(pred_MA, label = 'pred')
plt.legend()

# %% [markdown]
# # 인공신경망 모형

# %%
#모형 생성
NN = MLPRegressor(hidden_layer_sizes = 10, #은닉층 노드 개수
                  momentum = 0.1, #모멘텀
                  learning_rate_init = 0.1, #학습률
                  max_iter = 1000, #epoch
                  random_state = 1) # 모형 고정
#모형 학습
NN.fit(X_train, y_train)

#예측 값 생성
pred_NN = NN.predict(X_test)

#성과지표 확인
print('MAPE:', MAPE(pred_NN, y_test))
print('RMSE', RMSE(pred_NN, y_test))
# Out:
# MAPE: 3.0432577075516214
# RMSE 1987.9255336459921

# %%
plt.figure(figsize = (16,8))
plt.plot(pd.DataFrame(y_test), label = 'real')
plt.plot(pd.DataFrame(pred_NN, index = y_test.index), label = 'pred')
plt.legend()

# %% [markdown]
# # 순환 신경망 모형

# %%
#모형 구축
model = Sequential()
model.add(SimpleRNN(12, input_shape=(5,1), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam', metrics=['acc'])

# %%
#keras 입력값 형식 변경
train_x = X_train.values.reshape(X_train.shape[0],5,1) #행 길이, 변수 개수, 차원(1)
test_x = X_test.values.reshape(X_test.shape[0],5,1)

# %%
#학습하기
epochs = 40
batch_size = 2
model.fit(train_x, y_train,
          batch_size=batch_size,
          epochs=epochs,
          shuffle=False)
# Out:
# Epoch 1/40
# 147/147 [==============================] - 0s 973us/step - loss: 45253100.0000 - acc: 0.0000e+00
# Epoch 2/40
# 147/147 [==============================] - 0s 945us/step - loss: 44116456.0000 - acc: 0.0000e+00
# Epoch 3/40
# 147/147 [==============================] - 0s 979us/step - loss: 43069300.0000 - acc: 0.0000e+00
# Epoch 4/40
# 147/147 [==============================] - 0s 973us/step - loss: 41849936.0000 - acc: 0.0000e+00
# Epoch 5/40
# 147/147 [==============================] - 0s 884us/step - loss: 40794092.0000 - acc: 0.0000e+00
# Epoch 6/40
# 147/147 [==============================] - 0s 877us/step - loss: 39428360.0000 - acc: 0.0000e+00
# Epoch 7/40
# 147/147 [==============================] - 0s 897us/step - loss: 38048336.0000 - acc: 0.0000e+00
# Epoch 8/40
# 147/147 [==============================] - 0s 897us/step - loss: 36755348.0000 - acc: 0.0000e+00
# Epoch 9/40
# 147/147 [==============================] - 0s 897us/step - loss: 35922448.0000 - acc: 0.0000e+00
# Epoch 10/40
# 147/147 [==============================] - 0s 877us/step - loss: 34302076.0000 - acc: 0.0000e+00
# Epoch 11/40
# 147/147 [==============================] - 0s 849us/step - loss: 33567556.0000 - acc: 0.0000e+00
# Epoch 12/40
# 147/147 [==============================] - 0s 870us/step - loss: 33053742.0000 - acc: 0.0000e+00
# Epoch 13/40
# 147/147 [==============================] - 0s 873us/step - loss: 33086736.0000 - acc: 0.0000e+00
# Epoch 14/40
# 147/147 [==============================] - 0s 890us/step - loss: 34366308.0000 - acc: 0.0000e+00
# Epoch 15/40
# 147/147 [==============================] - 0s 938us/step - loss: 38045100.0000 - acc: 0.0000e+00
# Epoch 16/40
# 147/147 [==============================] - 0s 938us/step - loss: 46430332.0000 - acc: 0.0000e+00
# Epoch 17/40
# 147/147 [==============================] - 0s 945us/step - loss: 52608940.0000 - acc: 0.0000e+00
# Epoch 18/40
# 147/147 [==============================] - 0s 890us/step - loss: 31123754.0000 - acc: 0.0000e+00
# Epoch 19/40
# 147/147 [==============================] - 0s 945us/step - loss: 18297454.0000 - acc: 0.0000e+00
# Epoch 20/40
# 147/147 [==============================] - 0s 904us/step - loss: 17894344.0000 - acc: 0.0000e+00
# Epoch 21/40
# 147/147 [==============================] - 0s 918us/step - loss: 18548686.0000 - acc: 0.0000e+00
# Epoch 22/40
# 147/147 [==============================] - 0s 925us/step - loss: 18300416.0000 - acc: 0.0000e+00
# Epoch 23/40
# 147/147 [==============================] - 0s 941us/step - loss: 18073078.0000 - acc: 0.0000e+00
# Epoch 24/40
# 147/147 [==============================] - 0s 938us/step - loss: 17062374.0000 - acc: 0.0000e+00
# Epoch 25/40
# 147/147 [==============================] - 0s 884us/step - loss: 16251548.0000 - acc: 0.0000e+00
# Epoch 26/40
# 147/147 [==============================] - 0s 870us/step - loss: 15623332.0000 - acc: 0.0000e+00
# Epoch 27/40
# 147/147 [==============================] - 0s 938us/step - loss: 14941443.0000 - acc: 0.0000e+00
# Epoch 28/40
# 147/147 [==============================] - 0s 897us/step - loss: 14499077.0000 - acc: 0.0000e+00
# Epoch 29/40
# 147/147 [==============================] - 0s 856us/step - loss: 13937341.0000 - acc: 0.0000e+00
# Epoch 30/40
# 147/147 [==============================] - 0s 884us/step - loss: 13321354.0000 - acc: 0.0000e+00
# Epoch 31/40
# 147/147 [==============================] - 0s 1ms/step - loss: 12948509.0000 - acc: 0.0000e+00
# Epoch 32/40
# 147/147 [==============================] - 0s 938us/step - loss: 12522759.0000 - acc: 0.0000e+00
# Epoch 33/40
# 147/147 [==============================] - 0s 911us/step - loss: 12083283.0000 - acc: 0.0000e+00
# Epoch 34/40
# 147/147 [==============================] - 0s 932us/step - loss: 11706169.0000 - acc: 0.0000e+00
# Epoch 35/40
# 147/147 [==============================] - 0s 959us/step - loss: 11458335.0000 - acc: 0.0000e+00
# Epoch 36/40
# 147/147 [==============================] - 0s 853us/step - loss: 11051049.0000 - acc: 0.0000e+00
# Epoch 37/40
# 147/147 [==============================] - 0s 863us/step - loss: 10851720.0000 - acc: 0.0000e+00
# Epoch 38/40
# 147/147 [==============================] - 0s 911us/step - loss: 10438468.0000 - acc: 0.0000e+00
# Epoch 39/40
# 147/147 [==============================] - 0s 1ms/step - loss: 10313963.0000 - acc: 0.0000e+00
# Epoch 40/40
# 147/147 [==============================] - 0s 973us/step - loss: 9986598.0000 - acc: 0.0000e+00

# %%
pred_RNN = model.predict(test_x)
#성과지표 확인
print('MAPE:', MAPE(pred_RNN, pd.DataFrame(y_test).values))
print('RMSE', RMSE(pred_RNN, pd.DataFrame(y_test).values))
# Out:
# MAPE: 3.333173353380223
# RMSE 2207.9075104337794

# %%
plt.figure(figsize = (16,8))
plt.plot(pd.DataFrame(y_test), label = 'real')
plt.plot(pd.DataFrame(pred_RNN, index = y_test.index), label = 'pred')
plt.legend()
