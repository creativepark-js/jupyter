# %%
def solution(lottos, win_nums):
    answer = []   
    c = set(a) & set(b)
    d = [i for i in a if i in b]
    return answer

# %%
def solution(a, b):
    answer = []
    c = set(a) & set(b)
    d = [i for i in a if i in b]
    e = len(d)
    if e == 6 :
        answer.append(1)
        count = a.count(0)
        g = 1 - count
        answer.append(g)
    elif e == 5:
        answer.append(2)
        count = a.count(0)
        g = 2 - count
        answer.append(g)
    elif e == 4:
        answer.append(3)
        count = a.count(0)
        g = 3 - count
        answer.append(g)
    elif e == 3:
        answer.append(4)
        count = a.count(0)
        g = 4 - count
        answer.append(g)
    elif e == 2:
        answer.append(5)
        count = a.count(0)
        g = 5 - count
        answer.append(g)
    elif e == 1:
        answer.append(6)
        count = a.count(0)
        g = 6 - count
        answer.appned(g)
    else :
        answer.append(6)
        count = a.count(0)
        if count in [0,1]:
            g= 6
        else:
            g = 7 - count
        answer.append(g)

    answer.sort()
    return answer

# %%
def solution(a,b):
    answer = []
    count = 0
    count_0 = 0
    for i in a:
        if i == 0:
            count_0 += 1
        elif i in win_nums:
            count += 1
    
    result = [count + count_0 , count]
    
    for correct in result:
        if correct == 6:
            answer.append(1)
        elif correct == 5:
            answer.append(2)
        elif correct == 4:
            answer.append(3)
        elif correct == 3:
            answer.append(4)
        elif correct == 2:
            answer.append(5)
        else :
            answer.append(6)
            
    return answer

# %%
def solution(lottos, win_nums):
    counter = 0
    count0 = 0
    for i in lottos:
        if i == 0:
            count0 += 1
        else:   
            for j in win_nums:
                if i ==j:
                    counter += 1 
    best = count0+counter
    worst = counter
    if best != 0:
        bestrank = 7-best
    else:
        bestrank = 6

    if worst != 0:
        worstrank = 7-worst
    else:
        worstrank = 6

    answer = [bestrank,worstrank]
    return answer

# %%
numbers = [1,4,7,3,6,9]
answer = []
left = [1,4,7]
right = [3,6,9]
main = [2,5,8,0]
floor1 = [1,2,3]
floor2 = [4,5,6]
floor3 = [7,8,9]
floor4 = [0]
left_hand_index = 0
right_hand_index = 0
floor_index = 0
if hand == "right":
    position = "R"
else :
    postion = "L"
for i in numbers:
    if i in left:
        answer.append("L")
        if i in floor1:
            left_hand_index = 1
        elif i in floor2:
            left_hand_index = 2
        elif i in floor3:
            left_hand_index = 3
        else :
            left_hand_index = 4
        
    
    elif i in right:
        answer.append("R")
        if i in floor1:
            right_hand_index = 1
        elif i in floor2:
            right_hand_index = 2
        elif i in floor3:
            right_hand_index = 3
        else :
            right_hand_index = 4
            
    elif i in main :
        if i in floor1:
            floor_index = 1
        elif i in floor2:
            floor_index = 2
        elif i in floor3:
            floor_index = 3
        else :
            floor_index = 4
            
            if abs(left_hand_index - floor_index) < abs(right_hand_index - floor_index):
                answer.append("L")
                left_hand_index = floor_index
            
            elif abs(left_hand_index - floor_index) < abs(right_hand_index - floor_index):
                answer.append("R")
                right_hand_index = floor_index
            
            else :
                answer.append(position)


Str_answer = "".join(answer)
print(Str_answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-aad1b02ce378> in <module>
#      11 right_hand_index = 0
#      12 floor_index = 0
# ---> 13 if hand == "right":
#      14     position = "R"
#      15 else :
#
# NameError: name 'hand' is not defined

# %%
def solution(numbers, hand):
    answer = []
    left = [1,4,7]
    right = [3,6,9]
    main = [2,5,8,0]
    floor1 = [1,2,3]
    floor2 = [4,5,6]
    floor3 = [7,8,9]
    floor4 = [0]
    
    left_hand_index = 0
    right_hand_index = 0
    floor_index = 0
    if hand == "right":
        position = "R"
        
    else :
        postion = "L"
        
    for i in numbers:
        if i in left:
            answer.append("L")
            if i in floor1:
                left_hand_index = 1
            elif i in floor2:
                left_hand_index = 2
            elif i in floor3:
                left_hand_index = 3
            else :
                left_hand_index = 4


        elif i in right:
            answer.append("R")
            if i in floor1:
                right_hand_index = 1
            elif i in floor2:
                right_hand_index = 2
            elif i in floor3:
                right_hand_index = 3
            else :
                right_hand_index = 4

        elif i in main :
            if i in floor1:
                floor_index = 1
                if abs(left_hand_index - floor_index) < abs(right_hand_index - floor_index):
                    answer.append("L")
                    left_hand_index = floor_index

                elif abs(left_hand_index - floor_index) > abs(right_hand_index - floor_index):
                    answer.append("R")
                    right_hand_index = floor_index

                else :
                    answer.append(position)
                    
                    
                    
            elif i in floor2:
                floor_index = 2
                if abs(left_hand_index - floor_index) < abs(right_hand_index - floor_index):
                    answer.append("L")
                    left_hand_index = floor_index

                elif abs(left_hand_index - floor_index) > abs(right_hand_index - floor_index):
                    answer.append("R")
                    right_hand_index = floor_index

                else :
                    answer.append(position)
                    
                    
            elif i in floor3:
                floor_index = 3
                if abs(left_hand_index - floor_index) < abs(right_hand_index - floor_index):
                    answer.append("L")
                    left_hand_index = floor_index

                elif abs(left_hand_index - floor_index) > abs(right_hand_index - floor_index):
                    answer.append("R")
                    right_hand_index = floor_index

                else :
                    answer.append(position)
                    
            else :
                floor_index = 4
                if abs(left_hand_index - floor_index) < abs(right_hand_index - floor_index):
                    answer.append("L")
                    left_hand_index = floor_index

                elif abs(left_hand_index - floor_index) > abs(right_hand_index - floor_index):
                    answer.append("R")
                    right_hand_index = floor_index

                else :
                    answer.append(position)
                    

                if abs(left_hand_index - floor_index) < abs(right_hand_index - floor_index):
                    answer.append("L")
                    left_hand_index = floor_index

                elif abs(left_hand_index - floor_index) > abs(right_hand_index - floor_index):
                    answer.append("R")
                    right_hand_index = floor_index

                else :
                    answer.append(position)
                    


    answer = "".join(answer)
    

    
    
    return answer
solution([7,0,8,2,8,3,1,5,7,6,2],"left")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-21-ec203bf8a346> in <module>
#     118
#     119     return answer
# --> 120 solution([7,0,8,2,8,3,1,5,7,6,2],"left")
#
# <ipython-input-21-ec203bf8a346> in solution(numbers, hand)
#      69
#      70                 else :
# ---> 71                     answer.append(position)
#      72
#      73
#
# UnboundLocalError: local variable 'position' referenced before assignment

# %%
def solution(numbers,hand):
    answer = []
    phone = [[1,4,7,"*"],[2,5,8,0],[3,6,9,"#"]]
    left_hand=["*"]
    right_hand=["#"]
    for i in numbers:
        if i in phone[0]:
            answer.append('l')
            left_hand.append(i)
        elif i in phone[2]:
            answer.append('r')
            right_hand.append(i)
        elif i in phone[1]:
            check = phone[1].index(i) 
            if left_hand[-1] in phone[0]:
                left_handl=abs(phone[0].index(left_hand[-1])-check)+1
            elif left_hand[-1] in phone[1]:
                left_handl=abs(phone[1].index(left_hand[-1])-check)
            if right_hand[-1] in phone[2]:
                right_handl=abs(phone[2].index(right_hand[-1]) -check)+1
            elif right_hand[-1] in phone[1]:
                right_handl = abs(phone[1].index(right_hand[-1]-check)
            if left_handl < right_handl :
                                  
                                  
                answer.append('l')
                left_hand.append(i)
            elif (left_handl > right_handl) :
                answer.append('r')
                right_hand.append(i)
            else :
                if hand == "left" :
                    answer.append("l")
                    left_hand.append(i)
                elif hand == "right" :
                    ansswer.appned('r')
                    right_hand.append(i)
# Out:
#   File "<ipython-input-23-fd1b1e4cdfb8>", line 24
#     if (left_handl < right_handl) :
#                                   ^
# SyntaxError: invalid syntax

# %%
# k번째 수

def solution(array,commands):
    answer = []
    for i in commands:
        newlist = [x for x in array[i[0]:i[1]]]
        newlist = sorted(newlist)
        answer.append(newlist[i[2]])
    return answer

# %%
array = [1, 5, 2, 6, 3, 7, 4]
commands = [[2, 5, 3], [4, 4, 1], [1, 7, 3]]
answer = []
for i in commands:
    answer.append(sorted([x for x in array[(i[0]-1):i[1]]])[(i[2]-1)])
    
    

print(answer)
# Out:
# [5, 6, 3]
